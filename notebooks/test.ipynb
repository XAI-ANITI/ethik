# %%
import numpy as np
import pandas as pd
import ethik
from sklearn import metrics

# %%
X = pd.DataFrame({
    "x0": [1, 2, 3],
    "x1": [7, 23, 30]
})

# %%
explainer = ethik.Explainer()

# %%
explainer.fit(X)

# %%
explainer.plot_predictions(X, [0, 1, 0])

# %%
explainer.plot_metric(X, [0, 0, 1], [0, 1, 0], metrics.accuracy_score)

# %%
X2 = pd.DataFrame({
    "x0": [1, 12, 56]
})
explainer2 = ethik.Explainer()
explainer2.fit(X2)

# %%
explainer2.plot_predictions(X2, [0, 1, 0])

# %%
explainer2.plot_metric(X2, [0, 0, 1], [0, 1, 0], metrics.accuracy_score)
